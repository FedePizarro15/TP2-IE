# %%
from functions import *

FILES = ['texts/adn.txt', 'texts/mitología.txt', 'texts/tabla.txt']

# %% [markdown]
# # Ejercicio 1

# %%
for file in FILES:
    prob_dict = probability_mass(file)

    bar_graph(prob_dict)

# %% [markdown]
# # Ejercicio 2

# %%
for file in FILES:
    exercise_2(file)
# Out:
# ============================================================
# Análisis de: texts/adn.txt
# ============================================================
# Longitud promedio de bits (Huffman): 2.0000
# Bits por símbolo (uniforme): 2
# Total de caracteres: 3780
# Bits totales (Huffman): 7560
# Bits totales (uniforme): 7560
# Reducción de memoria: 0.00%
# Primeros 100 bits codificados: 0010011111100001100011011011000110110010011100100111001010011111000110001101101100100111001001110010...
#
# ============================================================
# Análisis de: texts/mitología.txt
# ============================================================
# Longitud promedio de bits (Huffman): 4.3662
# Bits por símbolo (uniforme): 6
# Total de caracteres: 4749
# Bits totales (Huffman): 20735
# Bits totales (uniforme): 28494
# Reducción de memoria: 27.23%
# Primeros 100 bits codificados: 1010110001111110001011000111011011001110110010000101010111110101011000010010001100101011111110011110...
#
# ============================================================
# Análisis de: texts/tabla.txt
# ============================================================
# Longitud promedio de bits (Huffman): 3.5301
# Bits por símbolo (uniforme): 6
# Total de caracteres: 5146
# Bits totales (Huffman): 18166
# Bits totales (uniforme): 30876
# Reducción de memoria: 41.16%
# Primeros 100 bits codificados: 0101111001101101011010110100010111101001011110110101111100010110101110000110101101000101111010010111...

# %% [markdown]
# # Ejercicio 3

# %%
for file in FILES:
    compare_entropy_and_length(file)
# Out:
# ============================================================
# Ejercicio 3 — Análisis de: texts/adn.txt
# ============================================================
# Símbolos distintos (N): 4
# Entropía H(X): 1.999999 bits/símbolo
# Longitud promedio L (Huffman): 2.000000 bits/símbolo
# Brecha L - H: 0.000001 bits/símbolo
# Eficiencia H/L: 1.0000
# Cota de Huffman (H ≤ L < H+1): True
#
# ============================================================
# Ejercicio 3 — Análisis de: texts/mitología.txt
# ============================================================
# Símbolos distintos (N): 59
# Entropía H(X): 4.332977 bits/símbolo
# Longitud promedio L (Huffman): 4.366182 bits/símbolo
# Brecha L - H: 0.033206 bits/símbolo
# Eficiencia H/L: 0.9924
# Cota de Huffman (H ≤ L < H+1): True
#
# ============================================================
# Ejercicio 3 — Análisis de: texts/tabla.txt
# ============================================================
# Símbolos distintos (N): 52
# Entropía H(X): 3.480857 bits/símbolo
# Longitud promedio L (Huffman): 3.530120 bits/símbolo
# Brecha L - H: 0.049264 bits/símbolo
# Eficiencia H/L: 0.9860
# Cota de Huffman (H ≤ L < H+1): True

# %% [markdown]
# # Ejercicio 4

# %%
for file in FILES:
    analyze_normalized_entropy(file)
# Out:
# ============================================================
# Ejercicio 4 — Entropía normalizada: texts/adn.txt
# ============================================================
# Símbolos distintos (N): 4
# Entropía H(X): 1.999999 bits/símbolo
# Entropía normalizada η = H/log2(N): 1.000000 (adimensional, 0–1)
# Interpretación: Distribución cercana a uniforme (muy dispersa).
#
# ============================================================
# Ejercicio 4 — Entropía normalizada: texts/mitología.txt
# ============================================================
# Símbolos distintos (N): 59
# Entropía H(X): 4.332977 bits/símbolo
# Entropía normalizada η = H/log2(N): 0.736570 (adimensional, 0–1)
# Interpretación: Distribución intermedia: cierta estructura, cierta aleatoriedad.
#
# ============================================================
# Ejercicio 4 — Entropía normalizada: texts/tabla.txt
# ============================================================
# Símbolos distintos (N): 52
# Entropía H(X): 3.480857 bits/símbolo
# Entropía normalizada η = H/log2(N): 0.610630 (adimensional, 0–1)
# Interpretación: Distribución intermedia: cierta estructura, cierta aleatoriedad.
